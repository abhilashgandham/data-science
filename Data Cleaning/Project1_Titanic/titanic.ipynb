# %%
import pandas as pd
x = pd.read_csv(r'C:\Users\Abhilash Gandham\Desktop\Project1_Titanic\train.csv')

# %%
x.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
replacement_value = x[(x['Sex'] == 'male')&(x['Name'].str.contains('Mr.'))]['Age'].mean()

# %%
x[(x['Sex'] == 'male')&(x['Name'].str.contains('Mr.'))]['Age'].mean()
# Out:
# 32.409774436090224

# %%
print(replacement_value)
# Out:
# 32.409774436090224

# %%
x.loc[(x['Sex'] == 'male')&(x['Name'].str.contains('Mr.')),'Age'].fillna(replacement_value,inplace = True)

# %%
y = x.loc[(x['Sex'] == 'male')&(x['Name'].str.contains('Mr.')),'Age']

# %%
x.loc[(x['Sex'] == 'male')&(x['Name'].str.contains('Mr.')),'Age']
# Out:
# 0      22.0
# 4      35.0
# 5       NaN
# 6      54.0
# 12     20.0
# 13     39.0
# 17      NaN
# 20     35.0
# 21     34.0
# 23     28.0
# 26      NaN
# 27     19.0
# 29      NaN
# 33     66.0
# 34     28.0
# 35     42.0
# 36      NaN
# 37     21.0
# 42      NaN
# 45      NaN
# 46      NaN
# 48      NaN
# 51     21.0
# 54     65.0
# 55      NaN
# 57     28.5
# 60     22.0
# 62     45.0
# 64      NaN
# 67     19.0
#        ...
# 836    21.0
# 837     NaN
# 838    32.0
# 839     NaN
# 840    20.0
# 841    16.0
# 843    34.5
# 844    17.0
# 845    42.0
# 846     NaN
# 847    35.0
# 851    74.0
# 857    51.0
# 859     NaN
# 860    41.0
# 861    21.0
# 864    24.0
# 867    31.0
# 868     NaN
# 870    26.0
# 872    33.0
# 873    47.0
# 876    20.0
# 877    19.0
# 878     NaN
# 881    33.0
# 883    28.0
# 884    25.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 518, dtype: float64

# %%
y[y.isnull()] = y.mean()

# %%
x
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
z = x.loc[(x['Sex'] == 'female')&(x['Name'].str.contains('Mrs.')),'Age']

# %%
z[z.isnull()] = z.mean()

# %%
p = x.loc[(x['Sex'] == 'female')&(x['Name'].str.contains('Miss.')),'Age']

# %%
p[p.isnull()] = p.mean()

# %%
a = [z,p,y]

# %%
result = pd.concat(a)

# %%
x['Age+y'] = y
x['Age+p'] = p
x['Age+z'] = z
x['Age+q'] = q

# %%
x
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
q = x.loc[(x['Sex'] == 'male')&(x['Name'].str.contains('Master.')),'Age']
q[q.isnull()] = q.mean()

# %%
w = []
for i in x.index.values:
        if(x['Age+y'][i] is not np.nan):
            w.append(x['Age+y'][i])
        elif(x['Age+z'][i] is not np.nan):
            w.append(x['Age+z'][i])
        elif(x['Age+p'][i] is not np.nan):
            w.append(x['Age+p'][i])
        elif(x['Age+q'][i] is not np.nan):
            w.append(x['Age+q'][i])

# %%
w
# Out:
# [22.0,
#  nan,
#  nan,
#  nan,
#  35.0,
#  32.409774436090224,
#  54.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  20.0,
#  39.0,
#  nan,
#  nan,
#  nan,
#  32.409774436090224,
#  nan,
#  nan,
#  35.0,
#  34.0,
#  nan,
#  28.0,
#  nan,
#  nan,
#  32.409774436090224,
#  19.0,
#  nan,
#  32.409774436090224,
#  nan,
#  nan,
#  nan,
#  66.0,
#  28.0,
#  42.0,
#  32.409774436090224,
#  21.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  32.409774436090224,
#  nan,
#  nan,
#  32.409774436090224,
#  32.409774436090224,
#  nan,
#  32.409774436090224,
#  nan,
#  nan,
#  21.0,
#  nan,
#  nan,
#  65.0,
#  32.409774436090224,
#  nan,
#  28.5,
#  nan,
#  nan,
#  22.0,
#  nan,
#  45.0,
#  nan,
#  32.409774436090224,
#  nan,
#  nan,
#  19.0,
#  nan,
#  26.0,
#  32.0,
#  nan,
#  21.0,
#  26.0,
#  32.0,
#  25.0,
#  32.409774436090224,
#  32.409774436090224,
#  nan,
#  nan,
#  22.0,
#  29.0,
#  nan,
#  28.0,
#  nan,
#  nan,
#  16.0,
#  32.409774436090224,
#  nan,
#  24.0,
#  29.0,
#  20.0,
#  46.0,
#  26.0,
# ...

# %%
import numpy as np

# %%
x['final'] = x[x.columns[12:]].apply(lambda l:','.join(l.dropna().astype(float).astype(str)),axis=1)

# %%
x
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
x[x['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  Age+y  Age+p  \
# 61   female  38.0      0      0  113572  80.0   B28      NaN    NaN   38.0
# 829  female  62.0      0      0  113572  80.0   B28      NaN    NaN    NaN
#
#      Age+z  Age+q final
# 61     NaN    NaN  38.0
# 829   62.0    NaN  62.0

# %%
x[x.duplicated('PassengerId')]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Age+y, Age+p, Age+z, Age+q, final]
# Index: []

# %%
x[x['Pclass'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Age+y, Age+p, Age+z, Age+q, final]
# Index: []

# %%
x[x['Pclass'].isin([1,2,3])]['Pclass'].shape
# Out:
# (891,)

# %%
x['Pclass'].shape
# Out:
# (891,)

# %%
x[x['Name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Age+y, Age+p, Age+z, Age+q, final]
# Index: []

# %%
w
# Out:
# [22.0,
#  nan,
#  nan,
#  nan,
#  35.0,
#  32.409774436090224,
#  54.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  20.0,
#  39.0,
#  nan,
#  nan,
#  nan,
#  32.409774436090224,
#  nan,
#  nan,
#  35.0,
#  34.0,
#  nan,
#  28.0,
#  nan,
#  nan,
#  32.409774436090224,
#  19.0,
#  nan,
#  32.409774436090224,
#  nan,
#  nan,
#  nan,
#  66.0,
#  28.0,
#  42.0,
#  32.409774436090224,
#  21.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  32.409774436090224,
#  nan,
#  nan,
#  32.409774436090224,
#  32.409774436090224,
#  nan,
#  32.409774436090224,
#  nan,
#  nan,
#  21.0,
#  nan,
#  nan,
#  65.0,
#  32.409774436090224,
#  nan,
#  28.5,
#  nan,
#  nan,
#  22.0,
#  nan,
#  45.0,
#  nan,
#  32.409774436090224,
#  nan,
#  nan,
#  19.0,
#  nan,
#  26.0,
#  32.0,
#  nan,
#  21.0,
#  26.0,
#  32.0,
#  25.0,
#  32.409774436090224,
#  32.409774436090224,
#  nan,
#  nan,
#  22.0,
#  29.0,
#  nan,
#  28.0,
#  nan,
#  nan,
#  16.0,
#  32.409774436090224,
#  nan,
#  24.0,
#  29.0,
#  20.0,
#  46.0,
#  26.0,
# ...

# %%
x
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
x[x['Ticket'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Age+y, Age+p, Age+z, Age+q, final]
# Index: []

# %%
x[x.duplicated('Ticket',keep = False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 3              4         1       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# 20            21         0       2
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 35            36         0       1
# 38            39         0       3
# 39            40         1       3
# 41            42         0       2
# 43            44         1       2
# 49            50         0       3
# 50            51         0       3
# 52            53         1       1
# 58            59         1       2
# 59            60         0       3
# 61            62         1       1
# 62            63         0       1
# ...

# %%
x[x['Ticket'] == 349909]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Age+y, Age+p, Age+z, Age+q, final]
# Index: []

# %%
x.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Age+y          float64
# Age+p          float64
# Age+z          float64
# Age+q          float64
# final           object
# dtype: object

# %%
x[x.Ticket.duplicated()]
# Out:
#      PassengerId  Survived  Pclass  \
# 24            25         0       3
# 71            72         0       3
# 88            89         1       1
# 117          118         0       2
# 119          120         0       3
# 120          121         0       2
# 122          123         0       2
# 124          125         0       1
# 125          126         1       3
# 137          138         0       1
# 147          148         0       3
# 164          165         0       3
# 167          168         0       3
# 169          170         0       3
# 171          172         0       3
# 172          173         1       3
# 180          181         0       3
# 182          183         0       3
# 193          194         1       2
# 195          196         1       1
# 201          202         0       3
# 206          207         0       3
# 229          230         0       3
# 230          231         1       1
# 233          234         1       3
# ...

# %%
x[x['Ticket']=='19950']
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 27            28         0       1  Fortune, Mr. Charles Alexander    male
# 88            89         1       1      Fortune, Miss. Mabel Helen  female
# 341          342         1       1  Fortune, Miss. Alice Elizabeth  female
# 438          439         0       1               Fortune, Mr. Mark    male
#
#       Age  SibSp  Parch Ticket   Fare        Cabin Embarked  Age+y  Age+p  \
# 27   19.0      3      2  19950  263.0  C23 C25 C27        S   19.0    NaN
# 88   23.0      3      2  19950  263.0  C23 C25 C27        S    NaN   23.0
# 341  24.0      3      2  19950  263.0  C23 C25 C27        S    NaN   24.0
# 438  64.0      1      4  19950  263.0  C23 C25 C27        S   64.0    NaN
#
#      Age+z  Age+q final
# 27     NaN    NaN  19.0
# 88     NaN    NaN  23.0
# 341    NaN    NaN  24.0
# 438    NaN    NaN  64.0

# %%
grouped = x.groupby(x['Ticket'])

# %%
x.sort_values('Ticket')
# Out:
#      PassengerId  Survived  Pclass  \
# 504          505         1       1
# 257          258         1       1
# 759          760         1       1
# 262          263         0       1
# 558          559         1       1
# 585          586         1       1
# 110          111         0       1
# 475          476         0       1
# 430          431         1       1
# 366          367         1       1
# 170          171         0       1
# 462          463         0       1
# 523          524         1       1
# 329          330         1       1
# 889          890         1       1
# 604          605         1       1
# 507          508         1       1
# 187          188         1       1
# 806          807         0       1
# 633          634         0       1
# 887          888         1       1
# 815          816         0       1
# 263          264         0       1
# 209          210         1       1
# 766          767         0       1
# ...

# %%
x['final'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 861    False
# 862    False
# 863    False
# 864    False
# 865    False
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: final, Length: 891, dtype: bool

# %%
x.loc[759]['final']
# Out:
# ''

# %%
type(x['final'])
# Out:
# pandas.core.series.Series

# %%
x['Name'].str.split(',').str[0].sort_values()
# Out:
# 845              Abbing
# 279              Abbott
# 746              Abbott
# 874             Abelson
# 308             Abelson
# 365               Adahl
# 401               Adams
# 40                Ahlin
# 855                 Aks
# 207            Albimona
# 810           Alexander
# 840            Alhomaki
# 784                 Ali
# 210                 Ali
# 730               Allen
# 4                 Allen
# 498             Allison
# 297             Allison
# 305             Allison
# 834               Allum
# 192     Andersen-Jensen
# 460            Anderson
# 119           Andersson
# 541           Andersson
# 610           Andersson
# 68            Andersson
# 146           Andersson
# 542           Andersson
# 13            Andersson
# 850           Andersson
#              ...
# 406            Widegren
# 377             Widener
# 371             Wiklund
# 673            Wilhelms
# 648              Willey
# 735            Williams
# 155            Williams
# ...

# %%
x[['Age','final']]
# Out:
#       Age          final
# 0    22.0           22.0
# 1    38.0           38.0
# 2    26.0           26.0
# 3    35.0           35.0
# 4    35.0           35.0
# 5     NaN  32.4097744361
# 6    54.0           54.0
# 7     2.0            2.0
# 8    27.0           27.0
# 9    14.0           14.0
# 10    4.0            4.0
# 11   58.0           58.0
# 12   20.0           20.0
# 13   39.0           39.0
# 14   14.0           14.0
# 15   55.0           55.0
# 16    2.0            2.0
# 17    NaN  32.4097744361
# 18   31.0           31.0
# 19    NaN  35.6428571429
# 20   35.0           35.0
# 21   34.0           34.0
# 22   15.0           15.0
# 23   28.0           28.0
# 24    8.0            8.0
# 25   38.0           38.0
# 26    NaN  32.4097744361
# 27   19.0           19.0
# 28    NaN  21.7739726027
# 29    NaN  32.4097744361
# ..    ...            ...
# 861  21.0           21.0
# 862  48.0           48.0
# 863   NaN  21.7739726027
# 864  24.0           24.0
# 865  42.0           42.0
# ...

# %%
x.replace(x['final'].loc)

# %%
ind = x[x['final'] == ''].index

# %%
for i in ind:
    x.replace(x['final'].loc[i],x['Age'].loc[i],inplace=True)

# %%
x[x['final'] == '']
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Age+y, Age+p, Age+z, Age+q, final]
# Index: []

# %%
x.dtypes
# Out:
# PassengerId    float64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Age+y          float64
# Age+p          float64
# Age+z          float64
# Age+q          float64
# final           object
# dtype: object

# %%
x['final']=x['final'].convert_objects(convert_numeric = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
x['final'].dtype
# Out:
# dtype('O')

# %%
x.replace('male',1,inplace = True)
x.replace('female',0,inplace = True)

# %%
import sklearn

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier()

# %%
clf.fit(x[['final','Sex','Pclass']],x['Survived'])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
x.replace(x.loc[199]['final'],27,inplace = True)

# %%
x[x['final'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Age+y, Age+p, Age+z, Age+q, final]
# Index: []

# %%
test_data = pd.read_csv(r'C:\Users\Abhilash Gandham\Desktop\Project1_Titanic\test.csv')

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
import pandas as pd
test_data = pd.read_csv(r'C:\Users\Abhilash Gandham\Desktop\Project1_Titanic\test.csv')
test_data.head()
y1 = test_data.loc[(test_data['Sex'] == 'male')&(test_data['Name'].str.contains('Mr.')),'Age']
y1[y1.isnull()] = y1.mean()
z1 = test_data.loc[(test_data['Sex'] == 'female')&(test_data['Name'].str.contains('Mrs.')),'Age']
z1[z1.isnull()] = z1.mean()
p1 = test_data.loc[(test_data['Sex'] == 'female')&(test_data['Name'].str.contains('Miss.')),'Age']
p1[p1.isnull()] = p1.mean()
q1 = test_data.loc[(test_data['Sex'] == 'male')&(test_data['Name'].str.contains('Master.')),'Age']
q1[q1.isnull()] = q1.mean()
test_data['Age+y'] = y1
test_data['Age+p'] = p1
test_data['Age+z'] = z1
test_data['Age+q'] = q1
test_data['final'] = test_data[test_data.columns[12:]].apply(lambda l:','.join(l.dropna().astype(float).astype(str)),axis=1)
ind = test_data[test_data['final'] == ''].index
for i in ind:
    test_data.replace(test_data['final'].loc[i],test_data['Age'].loc[i],inplace=True)
test_data['final']=test_data['final'].convert_objects(convert_numeric = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
test_data
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
test_data.replace('male',1,inplace = True)
test_data.replace('female',0,inplace = True)
blah = clf.predict(test_data[['final','Sex','Pclass']])

# %%
 from sklearn.model_selection import cross_val_score

# %%
blah.shape
# Out:
# (418,)

# %%
import sklearn.metrics

# %%
test_data[test_data['final'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Age+y, Age+p, Age+z, Age+q, final]
# Index: []
